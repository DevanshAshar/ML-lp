# %% [markdown]
# <a href="https://colab.research.google.com/github/DevanshAshar/ML-lp/blob/main/TimeSerie/airPass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/AirPassengers.csv")

# %%
df.head(5)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df['Month']=pd.to_datetime(df['Month'],infer_datetime_format=True)
df.head(5)
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
index_df=df.set_index(['Month'])
from datetime import datetime
index_df.head(5)
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
plt.xlabel("Date")
plt.ylabel("Passengers")
plt.plot(index_df)

# %%
from statsmodels.tsa.stattools import adfuller
test_result=adfuller(df['#Passengers'])
