# %% [markdown]
# <a href="https://colab.research.google.com/github/DevanshAshar/ML-lp/blob/main/LogisticRegression/suv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/suv_data.csv")

# %%
df.head(5)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.drop(['User ID','Gender'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
x=df.iloc[:,[0,1]].values
y=df.iloc[:,2].values

# %%
x
# Out:
# array([[    19,  19000],
#        [    35,  20000],
#        [    26,  43000],
#        [    27,  57000],
#        [    19,  76000],
#        [    27,  58000],
#        [    27,  84000],
#        [    32, 150000],
#        [    25,  33000],
#        [    35,  65000],
#        [    26,  80000],
#        [    26,  52000],
#        [    20,  86000],
#        [    32,  18000],
#        [    18,  82000],
#        [    29,  80000],
#        [    47,  25000],
#        [    45,  26000],
#        [    46,  28000],
#        [    48,  29000],
#        [    45,  22000],
#        [    47,  49000],
#        [    48,  41000],
#        [    45,  22000],
#        [    46,  23000],
#        [    47,  20000],
#        [    49,  28000],
#        [    47,  30000],
#        [    29,  43000],
#        [    31,  18000],
#        [    31,  74000],
#        [    27, 137000],
#        [    21,  16000],
#        [    28,  44000],
#        [    27,  90000],
#        [    35,  27000],
#        [    33,  28000],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,train_size=0.7)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
pred=lr.predict(X_test)

# %%
from sklearn.metrics import classification_report
classification_report(Y_test,pred)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,pred)
# Out:
# 0.675
