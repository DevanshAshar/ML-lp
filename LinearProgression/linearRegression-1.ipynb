# %% [markdown]
# <a href="https://colab.research.google.com/github/DevanshAshar/ML-lp/blob/main/LinearProgression/linearRegression-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
url = "https://raw.githubusercontent.com/devzohaib/Simple-Linear-Regression/master/tvmarketing.csv"
df = pd.read_csv(url)
print(df.head(10))
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# 5    8.7    7.2
# 6   57.5   11.8
# 7  120.2   13.2
# 8    8.6    4.8
# 9  199.8   10.6

# %%
print(df.shape)
# Out:
# (200, 2)

# %%
x = df.TV
y = df.Sales
plt.scatter(x,y)
plt.xlabel("TV")
plt.ylabel("Sales")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,train_size=0.6)
X_train = X_train[:, np.newaxis]
X_test = X_test[:, np.newaxis]
# Out:
# <ipython-input-24-426aaf98afed>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_train = X_train[:, np.newaxis]
# <ipython-input-24-426aaf98afed>:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_test = X_test[:, np.newaxis]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# (80, 1) (120, 1)
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [0.05276014]
# 6.518380804618565

# %%
Y_pred = lr.predict(X_test)
plt.scatter(X_test,Y_test)
plt.xlabel("Predicated")
plt.ylabel("Actual")
plt.plot(X_test,Y_pred,linestyle="dotted",color="red")
plt.show()

# %%
import pandas as pd
url2="https://raw.githubusercontent.com/codebasics/py/master/ML/1_linear_reg/Exercise/canada_per_capita_income.csv"
ds=pd.read_csv(url2)
print(ds.head(5))
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
x=ds.year
y=ds['per capita income (US$)']

# %%
from sklearn import linear_model
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(x,y)

# %%
reg=linear_model.LinearRegression()
import numpy as np
reg.fit(ds[['year']],ds['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
from sklearn import linear_model
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(x,y)
plt.plot(ds['year'],reg.predict(ds[['year']]),color='red')
